# %% [markdown]
# # 7 Minutes to Pywaterflood
#
# Here we will install _pywaterflood_, load a small (synthetic) waterflood's production and injection data, then perform _CRM_ to estimate the connectivities, predict production, and compare the predictions to historical production
#
# To install pywaterflood, run
#
# ```bash
# pip install pywaterflood
# ```
#
# on the command line.

# %%
import os

import matplotlib.pyplot as plt
import pandas as pd
from pywaterflood import CRM

# %% [markdown]
# ## Waterflood history matching
#
# First, we pull production from 4 wells and injection from 5 wells over a 298 timestep period, then we create a CRM instance where the time constants are for injector-producer pairs (per-pair) and connectivity constants are limited to 1 for each injector-producer pair. Next, we fit and predict historical production.

# %%
gh_url = "https://raw.githubusercontent.com/frank1010111/pywaterflood/master/testing/data/"
prod = pd.read_csv(gh_url + "production.csv", header=None)
inj = pd.read_csv(gh_url + "injection.csv", header=None)
time = pd.read_csv(gh_url + "time.csv", header=None)

num_threads = min(os.cpu_count(), prod.shape[1])

crm = CRM(tau_selection="per-pair", constraints="up-to one")
crm.fit(prod.to_numpy(), inj.to_numpy(), time.to_numpy()[:, 0], num_cores=num_threads)
q_hat = crm.predict()

# %%
fig, axes = plt.subplots(len(prod.columns), figsize=(6, 8), sharex=True, sharey=True)
for i, p in enumerate(prod):
    axes[i].plot(time, prod[p], label="Production")
    axes[i].plot(time, q_hat[:, i], ls="--", label="Prediction")
    axes[i].set(xlim=(0, None), ylim=(0, None), ylabel="Production rate")
    axes[i].annotate(f"Producer {p}", xy=(7000, 100))
axes[i].set(xlabel="Time")
# Out:
# [Text(0.5, 0, 'Time')]

# %% [markdown]
# ## Look at inter-well connectivity
#
# Let's make a table of the connectivity and highlight the most important injector for each producer.

# %%
connectivity = pd.DataFrame(
    crm.gains,
    index=prod.columns.rename("Producer"),
    columns=inj.columns.rename("Injector"),
)
connectivity.T.style.highlight_max().format("{:.2}")
# Out:
# <style type="text/css">
# #T_f51b1_row0_col1, #T_f51b1_row1_col0, #T_f51b1_row3_col3, #T_f51b1_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f51b1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Producer</th>
#       <th id="T_f51b1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f51b1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f51b1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f51b1_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Injector</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f51b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f51b1_row0_col0" class="data row0 col0" >0.32</td>
#       <td id="T_f51b1_row0_col1" class="data row0 col1" >0.33</td>
#       <td id="T_f51b1_row0_col2" class="data row0 col2" >0.18</td>
#       <td id="T_f51b1_row0_col3" class="data row0 col3" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_f51b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f51b1_row1_col0" class="data row1 col0" >0.33</td>
#       <td id="T_f51b1_row1_col1" class="data row1 col1" >0.18</td>
#       <td id="T_f51b1_row1_col2" class="data row1 col2" >0.33</td>
#       <td id="T_f51b1_row1_col3" class="data row1 col3" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_f51b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f51b1_row2_col0" class="data row2 col0" >0.25</td>
#       <td id="T_f51b1_row2_col1" class="data row2 col1" >0.24</td>
#       <td id="T_f51b1_row2_col2" class="data row2 col2" >0.25</td>
#       <td id="T_f51b1_row2_col3" class="data row2 col3" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_f51b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f51b1_row3_col0" class="data row3 col0" >0.17</td>
#       <td id="T_f51b1_row3_col1" class="data row3 col1" >0.33</td>
#       <td id="T_f51b1_row3_col2" class="data row3 col2" >0.17</td>
#       <td id="T_f51b1_row3_col3" class="data row3 col3" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_f51b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f51b1_row4_col0" class="data row4 col0" >0.18</td>
#       <td id="T_f51b1_row4_col1" class="data row4 col1" >0.17</td>
#       <td id="T_f51b1_row4_col2" class="data row4 col2" >0.33</td>
#       <td id="T_f51b1_row4_col3" class="data row4 col3" >0.33</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Perform pressure-compensated CRM
#
# In some cases, you will have reliable pressure data for the producers in your waterflood. This is useful additional data that can improve the capacitance resistance model predictions. The approach was established by [Yousef _et al._ (2006)](https://onepetro.org/REE/article-abstract/9/06/630/196295) and improved by [Kaviani _et al._ (2012)](https://www.sciencedirect.com/science/article/pii/S0920410512000915).

# %%
from pywaterflood import CrmCompensated

crm_p = CrmCompensated(tau_selection="per-pair", constraints="up-to one")
pressure = 1000 - prod.to_numpy() * 0.1  # allow us to make something up
crm_p.fit(prod.to_numpy(), pressure, inj.to_numpy(), time.to_numpy()[:, 0], num_cores=num_threads)
q_hat_p = crm_p.predict()

# %%
fig, axes = plt.subplots(len(prod.columns), figsize=(6, 8), sharex=True, sharey=True)
for i, p in enumerate(prod):
    axes[i].plot(time, prod[p], label="Production")
    axes[i].plot(time, q_hat_p[:, i], ls="--", label="Prediction")
    axes[i].set(xlim=(0, None), ylim=(0, None), ylabel="Production rate")
    axes[i].annotate(f"Producer {p}", xy=(7000, 100))
axes[i].set(xlabel="Time")
# Out:
# [Text(0.5, 0, 'Time')]
